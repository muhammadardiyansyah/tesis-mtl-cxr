# %%
import torch

print(torch.__version__)
# Out:
# 2.12.0+cpu

# %% [markdown]
# distribusi keseluruhan label

# %%
import pandas as pd

df = pd.read_csv(
    "../data/train/train.csv"
)

print(df["tb"].value_counts(dropna=False))

print()

print(
    df["cardiomegaly"]
    .value_counts(dropna=False)
)
# Out:
# tb
# -1    234801
#  0      5320
#  1       560
# Name: count, dtype: int64
#
# cardiomegaly
# -1    135589
#  0     84268
#  1     20824
# Name: count, dtype: int64

# %%
import os

tb_folder = "../data/raw/tbx11k/imgs/tb"
health_folder = "../data/raw/tbx11k/imgs/health"
sick_folder = "../data/raw/tbx11k/imgs/sick"

print("TB:", len(os.listdir(tb_folder)))
print("Healthy:", len(os.listdir(health_folder)))
print("Sick:", len(os.listdir(sick_folder)))
# Out:
# TB: 800
# Healthy: 3800
# Sick: 3800

# %%
import os

root = "../data/raw/tbx11k/imgs"

for folder in os.listdir(root):
    path = os.path.join(root, folder)

    if os.path.isdir(path):
        print(folder, len(os.listdir(path)))
# Out:
# extra 2
# health 3800
# sick 3800
# tb 800
# test 3302
